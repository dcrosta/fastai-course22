# %% [markdown]
# ## Is it a bird?

# %%
#NB: Kaggle requires phone verification to use the internet or a GPU. If you haven't done that yet, the cell below will fail
#    This code is only here to check that your internet is enabled. It doesn't do anything else.
#    Here's a help thread on getting your phone number verified: https://www.kaggle.com/product-feedback/135367

import socket,warnings
try:
    socket.setdefaulttimeout(1)
    socket.socket(socket.AF_INET, socket.SOCK_STREAM).connect(('1.1.1.1', 53))
except socket.error as ex:
    raise Exception("STOP: No internet. Click '>|' in top right and set 'Internet' switch to on")
print("Internet works")
# Out:
# Internet works

# %%
# It's a good idea to ensure you're running the latest version of any libraries you need.
# `!pip install -Uqq <libraries>` upgrades to the latest version of <libraries>
# NB: You can safely ignore any warnings or errors pip spits out about running as root or incompatibilities
import os
iskaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')

if iskaggle:
    # !pip install -Uqq fastai fastcore

# %% [markdown]
# In 2015 the idea of creating a computer system that could recognise birds was considered so outrageously challenging that it was the basis of [this XKCD joke](https://xkcd.com/1425/):

# %% [markdown]
# ![image.png](attachment:a0483178-c30e-4fdd-b2c2-349e130ab260.png)

# %% [markdown]
# But today, we can do exactly that, in just a few minutes, using entirely free resources!
#
# The basic steps we'll take are:
#
# 1. Use DuckDuckGo to search for images of "bird photos"
# 1. Use DuckDuckGo to search for images of "forest photos"
# 1. Fine-tune a pretrained neural network to recognise these two groups
# 1. Try running this model on a picture of a bird and see if it works.

# %% [markdown]
# ## Step 1: Download images of birds and non-birds

# %%
# Skip this cell if you already have duckduckgo_search installed
# !pip install -U fastai fastcore
# !pip install -U duckduckgo_search
# Out:
# Collecting fastai
#   Using cached fastai-2.7.13-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: fastcore in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (1.5.29)
# Requirement already satisfied: pip in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from fastai) (23.3.2)
# Requirement already satisfied: packaging in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from fastai) (23.2)
# Collecting fastdownload<2,>=0.0.5 (from fastai)
#   Using cached fastdownload-0.0.7-py3-none-any.whl (12 kB)
# Collecting torchvision>=0.11 (from fastai)
#   Using cached torchvision-0.16.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting matplotlib (from fastai)
#   Using cached matplotlib-3.8.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting pandas (from fastai)
#   Using cached pandas-2.1.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: requests in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from fastai) (2.31.0)
# Requirement already satisfied: pyyaml in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from fastai) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from fastai) (10.2.0)
# Collecting scikit-learn (from fastai)
#   Using cached scikit_learn-1.3.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: scipy in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from fastai) (1.11.4)
# Collecting spacy<4 (from fastai)
#   Using cached spacy-3.7.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (25 kB)
# Requirement already satisfied: torch<2.2,>=1.10 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from fastai) (2.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (2.0.8)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy<4->fastai)
#   Using cached preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.1.8 (from spacy<4->fastai)
#   Using cached thinc-8.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (15 kB)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (2.0.10)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy<4->fastai)
#   Using cached weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (4.66.1)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy<4->fastai)
#   Using cached pydantic-2.5.3-py3-none-any.whl.metadata (65 kB)
# Requirement already satisfied: jinja2 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (3.1.2)
# Requirement already satisfied: setuptools in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (65.5.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from spacy<4->fastai) (1.26.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from requests->fastai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from requests->fastai) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from requests->fastai) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from requests->fastai) (2023.11.17)
# Requirement already satisfied: filelock in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (4.9.0)
# Requirement already satisfied: sympy in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (1.12)
# Requirement already satisfied: networkx in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (3.2.1)
# Requirement already satisfied: fsspec in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (2023.12.2)
# Collecting contourpy>=1.0.1 (from matplotlib->fastai)
#   Using cached contourpy-1.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Requirement already satisfied: cycler>=0.10 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from matplotlib->fastai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from matplotlib->fastai) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from matplotlib->fastai) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from matplotlib->fastai) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from pandas->fastai) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from pandas->fastai) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from scikit-learn->fastai) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from scikit-learn->fastai) (3.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.6.0)
# Collecting pydantic-core==2.14.6 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai)
#   Using cached pydantic_core-2.14.6-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Requirement already satisfied: six>=1.5 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.1.8->spacy<4->fastai)
#   Using cached blis-0.7.11-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.1.8->spacy<4->fastai)
#   Using cached confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from jinja2->spacy<4->fastai) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from sympy->torch<2.2,>=1.10->fastai) (1.3.0)
# Using cached fastai-2.7.13-py3-none-any.whl (232 kB)
# Using cached spacy-3.7.2-cp311-cp311-macosx_11_0_arm64.whl (6.5 MB)
# Using cached torchvision-0.16.2-cp311-cp311-macosx_11_0_arm64.whl (1.5 MB)
# Using cached matplotlib-3.8.2-cp311-cp311-macosx_11_0_arm64.whl (7.5 MB)
# Using cached pandas-2.1.4-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
# Using cached scikit_learn-1.3.2-cp311-cp311-macosx_12_0_arm64.whl (9.4 MB)
# Using cached contourpy-1.2.0-cp311-cp311-macosx_11_0_arm64.whl (243 kB)
# Using cached preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl (128 kB)
# Using cached pydantic-2.5.3-py3-none-any.whl (381 kB)
# Using cached pydantic_core-2.14.6-cp311-cp311-macosx_11_0_arm64.whl (1.7 MB)
# Using cached thinc-8.2.2-cp311-cp311-macosx_11_0_arm64.whl (778 kB)
# Using cached weasel-0.3.4-py3-none-any.whl (50 kB)
# Using cached blis-0.7.11-cp311-cp311-macosx_11_0_arm64.whl (1.1 MB)
# Using cached confection-0.1.4-py3-none-any.whl (35 kB)
# Installing collected packages: pydantic-core, preshed, contourpy, blis, scikit-learn, pydantic, pandas, matplotlib, fastdownload, torchvision, confection, weasel, thinc, spacy, fastai
# Successfully installed blis-0.7.11 confection-0.1.4 contourpy-1.2.0 fastai-2.7.13 fastdownload-0.0.7 matplotlib-3.8.2 pandas-2.1.4 preshed-3.0.9 pydantic-2.5.3 pydantic-core-2.14.6 scikit-learn-1.3.2 spacy-3.7.2 thinc-8.2.2 torchvision-0.16.2 weasel-0.3.4
# Requirement already satisfied: duckduckgo_search in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (4.1.1)
# Requirement already satisfied: click>=8.1.7 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from duckduckgo_search) (8.1.7)
# Requirement already satisfied: lxml>=4.9.3 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from duckduckgo_search) (5.0.0)
# Requirement already satisfied: curl-cffi>=0.5.10 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from duckduckgo_search) (0.5.10)
# Requirement already satisfied: cffi>=1.12.0 in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from curl-cffi>=0.5.10->duckduckgo_search) (1.16.0)
# Requirement already satisfied: pycparser in /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages (from cffi>=1.12.0->curl-cffi>=0.5.10->duckduckgo_search) (2.21)

# %%
from duckduckgo_search import ddg_images
from fastcore.all import *

def search_images(term, max_images=200): return L(ddg_images(term, max_results=max_images)).itemgot('image')

# %% [markdown]
# Let's start by searching for a bird photo and seeing what kind of result we get. We'll start by getting URLs from a search:

# %%
urls = search_images('bird photos', max_images=1)
urls[0]
# Out:
# /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages/duckduckgo_search/compat.py:40: UserWarning: ddg_images is deprecated. Use DDGS().images() generator
#   warnings.warn("ddg_images is deprecated. Use DDGS().images() generator")
# 'https://images.pexels.com/photos/1661179/pexels-photo-1661179.jpeg?cs=srgb&dl=green-bird-1661179.jpg&fm=jpg'

# %% [markdown]
# ...and then download a URL and take a look at it:

# %%
from fastdownload import download_url
dest = 'bird.jpg'
download_url(urls[0], dest, show_progress=False)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=219x256>

# %% [markdown]
# Now let's do the same with "forest photos":

# %%
download_url(search_images('forest photos', max_images=1)[0], 'forest.jpg', show_progress=False)
Image.open('forest.jpg').to_thumb(256,256)
# Out:
# /Users/dcrosta/.pyenv/versions/3.11.4/envs/fastai/lib/python3.11/site-packages/duckduckgo_search/compat.py:40: UserWarning: ddg_images is deprecated. Use DDGS().images() generator
#   warnings.warn("ddg_images is deprecated. Use DDGS().images() generator")
# <PIL.Image.Image image mode=RGB size=256x170>

# %% [markdown]
# Our searches seem to be giving reasonable results, so let's grab 200 examples of each of "bird" and "forest" photos, and save each group of photos to a different folder:

# %%
searches = 'forest','bird'
path = Path('bird_or_not')
from time import sleep

for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{o} photo'))
    # sleep(10)  # Pause between searches to avoid over-loading server
    # download_images(dest, urls=search_images(f'{o} sun photo'))
    # sleep(10)
    # download_images(dest, urls=search_images(f'{o} shade photo'))
    # sleep(10)
    resize_images(path/o, max_size=400, dest=path/o)

# %% [markdown]
# ## Step 2: Train our model

# %% [markdown]
# Some photos might not download correctly which could cause our model training to fail, so we'll remove them:

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 3

# %% [markdown]
# To train a model, we'll need `DataLoaders`, which is an object that contains a *training set* (the images used to create a model) and a *validation set* (the images used to check the accuracy of a model -- not used during training). In `fastai` we can create that easily using a `DataBlock`, and view sample images from it:

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path)

dls.show_batch(max_n=6)

# %% [markdown]
# Here what each of the `DataBlock` parameters means:
#
#     blocks=(ImageBlock, CategoryBlock),
#
# The inputs to our model are images, and the outputs are categories (in this case, "bird" or "forest").
#
#     get_items=get_image_files,
#
# To find all the inputs to our model, run the `get_image_files` function (which returns a list of all image files in a path).
#
#     splitter=RandomSplitter(valid_pct=0.2, seed=42),
#
# Split the data into training and validation sets randomly, using 20% of the data for the validation set.
#
#     get_y=parent_label,
#
# The labels (`y` values) is the name of the `parent` of each file (i.e. the name of the folder they're in, which will be *bird* or *forest*).
#
#     item_tfms=[Resize(192, method='squish')]
#
# Before training, resize each image to 192x192 pixels by "squishing" it (as opposed to cropping it).

# %% [markdown]
# Now we're ready to train our model. The fastest widely used computer vision model is `resnet18`. You can train this in a few minutes, even on a CPU! (On a GPU, it generally takes under 10 seconds...)
#
# `fastai` comes with a helpful `fine_tune()` method which automatically uses best practices for fine tuning a pre-trained model, so we'll use that.

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /Users/dcrosta/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44.7M/44.7M [00:04<00:00, 11.1MB/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.636625</td>
#       <td>0.414514</td>
#       <td>0.109375</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.079137</td>
#       <td>0.081778</td>
#       <td>0.000000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.045035</td>
#       <td>0.012893</td>
#       <td>0.000000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.033562</td>
#       <td>0.002150</td>
#       <td>0.000000</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Generally when I run this I see 100% accuracy on the validation set (although it might vary a bit from run to run).
#
# "Fine-tuning" a model means that we're starting with a model someone else has trained using some other dataset (called the *pretrained model*), and adjusting the weights a little bit so that the model learns to recognise your particular dataset. In this case, the pretrained model was trained to recognise photos in *imagenet*, and widely-used computer vision dataset with images covering 1000 categories) For details on fine-tuning and why it's important, check out the [free fast.ai course](https://course.fast.ai/).

# %% [markdown]
# ## Step 3: Use our model (and build your own!)

# %% [markdown]
# Let's see what our model thinks about that bird we downloaded at the start:

# %%
is_bird,_,probs = learn.predict(PILImage.create('bird.jpg'))
print(f"This is a: {is_bird}.")
print(f"Probability it's a bird: {probs[0]:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is a: bird.
# Probability it's a bird: 1.0000

# %% [markdown]
# Good job, resnet18. :)
#
# So, as you see, in the space of a few years, creating computer vision classification models has gone from "so hard it's a joke" to "trivially easy and free"!
#
# It's not just in computer vision. Thanks to deep learning, computers can now do many things which seemed impossible just a few years ago, including [creating amazing artworks](https://openai.com/dall-e-2/), and [explaining jokes](https://www.datanami.com/2022/04/22/googles-massive-new-language-model-can-explain-jokes/). It's moving so fast that even experts in the field have trouble predicting how it's going to impact society in the coming years.
#
# One thing is clear -- it's important that we all do our best to understand this technology, because otherwise we'll get left behind!

# %% [markdown]
# Now it's your turn. Click "Copy & Edit" and try creating your own image classifier using your own image searches!
#
# If you enjoyed this, please consider clicking the "upvote" button in the top-right -- it's very encouraging to us notebook authors to know when people appreciate our work.
